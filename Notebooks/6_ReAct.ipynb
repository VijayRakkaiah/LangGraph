# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, ToolMessage
from langchain.tools import tool
from langchain_core.prompts import ChatPromptTemplate


from dotenv import load_dotenv
import os
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("OpenAI API Key is set.")
else:
    raise ValueError("OpenAI API Key is not set.")
# Out:
# OpenAI API Key is set.

# %%
llm = ChatOpenAI(model="gpt-5.4-nano")

# %% [markdown]
# # **TOOLS**

# %% [markdown]
# ### **DuckDuckGo Search Tool**

# %%
from langchain_community.tools import DuckDuckGoSearchRun

@tool
def search_duckduckgo(query: str) -> str:

    """This tool searches the latest news on DuckDuckGo for the given query and returns the results."""
    duck_search = DuckDuckGoSearchRun()
    return duck_search.invoke(query)

# %% [markdown]
# ### **Arxiv Query Tool**

# %%
from langchain_community.tools import ArxivQueryRun
from langchain_community.utilities import ArxivAPIWrapper

@tool
def arxiv_tool(query: str) -> str:

    """"This tool allows you to query the arXiv database for research papers."""
    arxiv_query = ArxivQueryRun(api_wrapper=ArxivAPIWrapper())
    return arxiv_query.invoke(query)

# %% [markdown]
# ### **Wikipedia Search Tool**

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

@tool
def wiki_tool(query: str):

    """This tool allows you to search Wikipedia for information on a given topic."""
    wiki_query = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
    return wiki_query.invoke(query)

# %% [markdown]
# ### **Custom Tool**

# %%
@tool
def personal_info(name: str):

    """Use this tool to get personal information about Alice, Bob, or Charlie. 
    """

    info = {
        "Alice": "Alice is a software engineer with 5 years of experience in AI.",
        "Bob": "Bob is a data scientist who loves working with large datasets.",
        "Charlie": "Charlie is a product manager with a background in tech startups."
    }
    return info.get(name, "No information available for this person.")

# %% [markdown]
# ### **TOOL BINDING**

# %%
tools = [search_duckduckgo, arxiv_tool, wiki_tool, personal_info]

llm_with_tools = llm.bind_tools(tools)

# %% [markdown]
# # **LangGraph Creation**

# %% [markdown]
# ### **Create Schema**

# %%
from typing import TypedDict, List 

class graph_schema(TypedDict):
    messages: List

# %% [markdown]
# ### **Create Node Functions**

# %%
def llm_node(state: graph_schema) -> graph_schema:
    
    messages = state['messages']

    # Prompt template for the LLM, including system instructions and the human input
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "You are a helpful assistant that can use tools to answer questions."),
            ("human", "{input}")
        ]
    )

    # LLM With Tools 
    # llm_with_tools 

    chain = prompt | llm_with_tools 

    response = chain.invoke({"input": messages})

    # Update the state with the new message
    state['messages'] = messages + [response]

    return state

# %%
# from langgraph.prebuilt import ToolNode
def tool_node(state: graph_schema) -> graph_schema:

    messages = state['messages']

    tools_by_name = {tool.name: tool for tool in tools}

    tool_results = []

    for tool_call in messages[-1].tool_calls:

        tool = tools_by_name[tool_call["name"]]

        observation = tool.invoke(tool_call["args"])

        tool_results.append(ToolMessage(content=observation, tool_call_id=tool_call["id"]))

    # Update the state with the tool results
    state['messages'] = messages + tool_results

    return state

# %% [markdown]
# ### **Create Conditional Edge Function**

# %%
def if_tool_call(state: graph_schema) -> str:

    last_message = state['messages'][-1]

    if last_message.tool_calls:
        return "tool_node"
    else:
        return "end"

# %% [markdown]
# ### **Create State Graph**

# %%
from langgraph.graph import StateGraph, START, END

graph = StateGraph(graph_schema)

# Add nodes to the graph
graph.add_node("llm_node", llm_node)
graph.add_node("tool_node", tool_node)

# Add edges between nodes
graph.add_edge(START, "llm_node")
graph.add_conditional_edges("llm_node", if_tool_call,{"tool_node": "tool_node", "end": END})
graph.add_edge("tool_node", "llm_node")
graph.add_edge("llm_node", END)


react_graph = graph.compile()

from IPython.display import Image, display

# You could see the errors with the below command
Image(react_graph.get_graph().draw_mermaid_png())

# %% [markdown]
# ### **Graph Invocation**

# %%
react_graph.invoke({"messages": [HumanMessage(content="What is the latest news on AI?")]})
# Out:
# {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayyvsvDbKIzqtjsk0xc0MIjfY7Mx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de791-e82c-7ba3-bea4-a2b9d23fbc00-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_IkeiJBwSVWKOdfD0YMaWuS4X', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_IkeiJBwSVWKOdfD0YMaWuS4X'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 797, 'total_tokens': 820, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dayyxlloj00bmyCFnmdEh7yz2k9cc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de791-f24e-7590-a70b-c6c2a46afd91-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_2Efwrh8tuWNRed5CFBUMcu1l', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 797, 'output_tokens': 23, 'total_tokens': 820, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Android Police. Latest. Alphabet Conference: Google Cloud Showcases Gemini Enterprise Agent Platform With Las Vegas Marathon Demo.Google Drive starts rolling out Ask Gemini and AI Overviews.', tool_call_id='call_2Efwrh8tuWNRed5CFBUMcu1l'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1336, 'total_tokens': 1359, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayyzmICusqOOGUDFmyGh73YhHGtC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de791-fc24-70a1-894d-887fa22a11c6-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_TFWnMDUDFB1s1fOdtBKOLONj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1336, 'output_tokens': 23, 'total_tokens': 1359, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_TFWnMDUDFB1s1fOdtBKOLONj'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1875, 'total_tokens': 1898, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dayz2muknv2J8UIBEWHPJiiaTfnsA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-053c-7960-9451-dea980c6c7e5-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_50ZnazlSN0wD8Zg2Y2qH84ri', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1875, 'output_tokens': 23, 'total_tokens': 1898, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_50ZnazlSN0wD8Zg2Y2qH84ri'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 2418, 'total_tokens': 2441, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dayz4M6MeZQlR93UlsiEEqrV9hB4B', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-0ea0-71e3-8af1-098da18af4b3-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_8Zvy8A7IGeXGHBO5VHKlmtjg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2418, 'output_tokens': 23, 'total_tokens': 2441, 'input_token_details': {'audio': 0, 'cache_read': 1664}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='Stay informed about the latest advancements in artificial intelligence and their impact on search engine optimization with our AI News category. Here, we dive into the latest advancements and discussions in the world of artificial intelligence, offering you a curated selection of articles ... By using these sources, you ll be able to access the latest AI news and stay informed about key trends in the industry. AI News | Latest AI Breakthroughs, AI Trends & AI Policy Updates – AGIYes ... AI!We specialize in delivering the latest and most ... Latest AI News is an online platform focused on delivering current information about developments in artificial intelligence.', tool_call_id='call_8Zvy8A7IGeXGHBO5VHKlmtjg'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 2905, 'total_tokens': 2928, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dayz7pcZDXGHQBgAzRkcYIHA2H60P', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-1a99-7ed0-bf83-3e251281cec9-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_FHUxbSPDcaO5cYOhP0fyaEic', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2905, 'output_tokens': 23, 'total_tokens': 2928, 'input_token_details': {'audio': 0, 'cache_read': 1664}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. Artificial Intelligence News. Everything on AI including futuristic robots with artificial intelligence, computer models of human intelligence and more. See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time. Wondering what's happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of.", tool_call_id='call_FHUxbSPDcaO5cYOhP0fyaEic'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 3390, 'total_tokens': 3413, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2688}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dayz9v8L4xxDKZC2y33Wxedfez0Hh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-2163-7ed3-86bc-49fa64765860-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_1h1HmJL62p8SorVbUfRNg2HY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3390, 'output_tokens': 23, 'total_tokens': 3413, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='14 hours ago - AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide. 1 day ago - News coverage on artificial intelligence and machine learning tech, the companies building them, and the ethical issues AI raises today. 1 day ago - Artificial Intelligence: Read latest updates on AI like Google AI, ChatGPT, Google Lamda, Bard chatbot and more along with latest news as AI technology advances and makes new progress. All get detailed articles on AI related queries like what is AI, types of artificial intelligence, its applications and future. 4 days ago - Find the latest Artificial Intelligence news from WIRED. See related science and technology articles, photos, slideshows and videos. ET AI Hackathon 2.0 showcases India’s growing emphasis on practical AI innovation · Future of Knowledge Work Summit 2026 Bengaluru: Redefining enterprise work in the AI era · AI-powered tool to create the auto-generated newsletter you want.', tool_call_id='call_1h1HmJL62p8SorVbUfRNg2HY'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 3953, 'total_tokens': 3976, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2688}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzBHZscaK3pkNxoE21NifievZNq', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-27ec-7673-9fea-04b8176537c4-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_RgsBQfN8XnWtoDzEeYLU855v', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3953, 'output_tokens': 23, 'total_tokens': 3976, 'input_token_details': {'audio': 0, 'cache_read': 2688}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_RgsBQfN8XnWtoDzEeYLU855v'),
#   AIMessage(content='Here’s a quick snapshot of the *latest AI news themes* that show up in current coverage (from major tech/news aggregations):\n\n- **AI governance & safety:** Reporting highlights calls (including from Sam Altman/industry voices) for **closer work between AI companies and governments** to prevent future harms.\n- **Bias and data issues:** A recent study warning that **when AI systems learn from AI-generated data/outputs, bias can propagate** (“bias travels too”).\n- **Big tech product updates (Google examples):** Coverage includes **enterprise AI features** and **new agent-style platforms/demos**, plus rollout items tied to Google’s AI assistants and “AI Overviews”-type functionality.\n- **Ongoing mainstream releases & enterprise adoption:** Multiple outlets reiterate active movement across **enterprise AI tooling, model/product rollouts, and applied AI events**.\n\nIf you tell me your preferred sources (e.g., **Reuters**, **Bloomberg**, **The Verge**, **Google News**) or your focus (**policy**, **chips**, **labs/research**, **tools for business**, **open-source models**), I can narrow this to a cleaner “top 5 headlines” list.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 244, 'prompt_tokens': 4460, 'total_tokens': 4704, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 3712}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzDSskm9CVksgrQ4WuIzYu76jZ8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019de792-2fa1-72f3-a256-039bf07ea4d3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4460, 'output_tokens': 244, 'total_tokens': 4704, 'input_token_details': {'audio': 0, 'cache_read': 3712}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
for chunk in react_graph.stream(
    {"messages": [HumanMessage(content="What is the latest news on AI?")]},
    stream_mode="updates"
):
    print(chunk)
# Out:
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY')]}}
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj')]}}
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
# {'tool_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_met ...
# {'llm_node': {'messages': [HumanMessage(content='What is the latest news on AI?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 265, 'total_tokens': 288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzFvBNfqKFrZklU9DE5APq6mkDS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-39ea-7222-b54b-326d55d8a143-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_5r7bjE1ojrTUpll85zJq3TOY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 265, 'output_tokens': 23, 'total_tokens': 288, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='The latest artificial intelligence news coverage focusing on the technology, tools and the companies building AI technology.Sam Altman said AI company will work more closely with governments to prevent future tragedies. Google News. Full coverage. Sort.When AI learns from AI, bias travels too, study warns. 11 days ago. By Chethan Kumar. Save for later. Share. More. All coverage. The Latest AI Breakthroughs, News, and Developments. Wondering what’s happening in the AI world? Here is the list of the latest AI breakthroughs, news,and developments you must be aware of. AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.All our premium content and latest tech news delivered straight to your inbox. Explore the cutting-edge work Google is doing in AI and machine learning.Get the latest news from Google in your inbox.', tool_call_id='call_5r7bjE1ojrTUpll85zJq3TOY'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 801, 'total_tokens': 824, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DayzHvMkeyjtw280vdJTH1nQrbJIf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019de792-42ac-7f53-9800-010292f22335-0', tool_calls=[{'name': 'search_duckduckgo', 'args': {'query': 'latest news on AI'}, 'id': 'call_vJk8DHdhyiTjE4UWxYs7rOXj', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 801, 'output_tokens': 23, 'total_tokens': 824, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Read full articles, watch videos, browse thousands of titles and more on the "Artificial intelligence" topic with Google News. 4 days ago · Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global impact. Read the latest on artificial intelligence and machine learning tech, the companies that are building them, and the ethical issues AI raises today. The No.1 Magazine, Website, Newsletter & Webinar service covering AI, Machine Learning, AR & VR, Data, Technology and AI Applications. 2 days ago · Can AI Be Trained to Predict the Past? See the latest on The AI Race. From breaking news to in-depth reporting, Bloomberg tracks the full story in real time.', tool_call_id='call_vJk8DHdhyiTjE4UWxYs7rOXj'), AIMessage(content='', additional_kwargs={'refusal': None}, response_meta ...
